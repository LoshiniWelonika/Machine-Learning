# %%
import pandas as pd

# %%
data = pd.read_csv('weather.csv')
data
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
data.shape
# Out:
# (16743, 14)

# %%
del data['Station.Code']

# %%
data
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
# ...

# %%
data=data.drop(columns=['Data.Precipitation','Date.Week of'])
data
# Out:
#         Date.Full  Date.Month  Date.Year Station.City Station.Location  \
# 0      2016-01-03           1       2016   Birmingham   Birmingham, AL
# 1      2016-01-03           1       2016   Huntsville   Huntsville, AL
# 2      2016-01-03           1       2016       Mobile       Mobile, AL
# 3      2016-01-03           1       2016   Montgomery   Montgomery, AL
# 4      2016-01-03           1       2016    Anchorage    Anchorage, AK
# ...           ...         ...        ...          ...              ...
# 16738  2017-01-01           1       2017       Casper       Casper, WY
# 16739  2017-01-01           1       2017     Cheyenne     Cheyenne, WY
# 16740  2017-01-01           1       2017       Lander       Lander, WY
# 16741  2017-01-01           1       2017      Rawlins      Rawlins, WY
# 16742  2017-01-01           1       2017     Sheridan     Sheridan, WY
#
#       Station.State  Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# ...

# %%
data.count()
# Out:
# Date.Full                    16743
# Date.Month                   16743
# Date.Year                    16743
# Station.City                 16743
# Station.Location             16743
# Station.State                16743
# Data.Temperature.Avg Temp    16743
# Data.Temperature.Max Temp    16743
# Data.Temperature.Min Temp    16743
# Data.Wind.Direction          16743
# Data.Wind.Speed              16743
# dtype: int64

# %%
data.head(20)
# Out:
#      Date.Full  Date.Month  Date.Year              Station.City  \
# 0   2016-01-03           1       2016                Birmingham
# 1   2016-01-03           1       2016                Huntsville
# 2   2016-01-03           1       2016                    Mobile
# 3   2016-01-03           1       2016                Montgomery
# 4   2016-01-03           1       2016                 Anchorage
# 5   2016-01-03           1       2016                   Annette
# 6   2016-01-03           1       2016                    Bethel
# 7   2016-01-03           1       2016                   Bettles
# 8   2016-01-03           1       2016                  Cold Bay
# 9   2016-01-03           1       2016                   Cordova
# 10  2016-01-03           1       2016  Delta Junction/Ft Greely
# 11  2016-01-03           1       2016                 Fairbanks
# 12  2016-01-03           1       2016                   Gulkana
# 13  2016-01-03           1       2016                     Homer
# ...

# %%
data['Data.Temperature.Max Temp']>39
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 16738    False
# 16739     True
# 16740    False
# 16741    False
# 16742    False
# Name: Data.Temperature.Max Temp, Length: 16743, dtype: bool

# %%
condition = (data['Data.Temperature.Max Temp']>39) & (data['Data.Temperature.Min Temp']<30)
filter = data[condition]
filter
# Out:
#         Date.Full  Date.Month  Date.Year    Station.City    Station.Location  \
# 35     2016-01-03           1       2016  Douglas Bisbee  Douglas Bisbee, AZ
# 36     2016-01-03           1       2016         Kingman         Kingman, AZ
# 39     2016-01-03           1       2016         Winslow         Winslow, AZ
# 40     2016-01-03           1       2016      Fort Smith      Fort Smith, AR
# 41     2016-01-03           1       2016        Harrison        Harrison, AR
# ...           ...         ...        ...             ...                 ...
# 16725  2017-01-01           1       2017         Olympia         Olympia, WA
# 16729  2017-01-01           1       2017          Yakima          Yakima, WA
# 16730  2017-01-01           1       2017         Beckley         Beckley, WV
# 16732  2017-01-01           1       2017          Elkins          Elkins, WV
# 16739  2017-01-01           1       2017        Cheyenne        Cheyenne, WY
#
# ...

# %%
filter.shape
# Out:
# (1494, 11)

# %%
data.describe()
# Out:
#          Date.Month     Date.Year  Data.Temperature.Avg Temp  \
# count  16743.000000  16743.000000               16743.000000
# mean       6.343128   2016.018933                  56.089112
# std        3.490723      0.136294                  18.798295
# min        1.000000   2016.000000                 -27.000000
# 25%        3.000000   2016.000000                  44.000000
# 50%        6.000000   2016.000000                  58.000000
# 75%        9.000000   2016.000000                  71.000000
# max       12.000000   2017.000000                 100.000000
#
#        Data.Temperature.Max Temp  Data.Temperature.Min Temp  \
# count               16743.000000               16743.000000
# mean                   66.042406                  45.642716
# std                    19.787954                  18.559263
# min                   -19.000000                 -35.000000
# 25%                    53.000000                  33.000000
# ...

# %%
import matplotlib.pyplot as plt

x = range(20)   # or len(data)

y1 = data['Data.Temperature.Max Temp'][:20]
y2 = data['Data.Temperature.Min Temp'][:20]

plt.plot(x, y1)
plt.plot(x, y2)

plt.show()
